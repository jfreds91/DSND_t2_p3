# %% [markdown]
# ### Implementing FunkSVD
#
# In this notebook we will take a look at writing our own function that performs FunkSVD, which will follow the steps you saw in the previous video.  If you find that you aren't ready to tackle this task on your own, feel free to skip to the following video where you can watch as I walk through the steps.
#
# To test our algorithm, we will run it on the subset of the data you worked with earlier.  Run the cell below to get started.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import sparse
import svd_tests as t
# %matplotlib inline

# Read in the datasets
movies = pd.read_csv('data/movies_clean.csv')
reviews = pd.read_csv('data/reviews_clean.csv')

del movies['Unnamed: 0']
del reviews['Unnamed: 0']

# Create user-by-item matrix
user_items = reviews[['user_id', 'movie_id', 'rating', 'timestamp']]
user_by_movie = user_items.groupby(['user_id', 'movie_id'])['rating'].max().unstack()

# Create data subset
user_movie_subset = user_by_movie[[73486, 75314,  68646, 99685]].dropna(axis=0)
ratings_mat = np.matrix(user_movie_subset)
print(ratings_mat)
# Out:
# [[ 10.  10.  10.  10.]
#  [ 10.   4.   9.  10.]
#  [  8.   9.  10.   5.]
#  [  9.   8.  10.  10.]
#  [ 10.   5.   9.   9.]
#  [  6.   4.  10.   6.]
#  [  9.   8.  10.   9.]
#  [ 10.   5.   9.   8.]
#  [  7.   8.  10.   8.]
#  [  9.   5.   9.   7.]
#  [  9.   8.  10.   8.]
#  [  9.  10.  10.   9.]
#  [ 10.   9.  10.   8.]
#  [  5.   8.   5.   8.]
#  [ 10.   8.  10.  10.]
#  [  9.   9.  10.  10.]
#  [  9.   8.   8.   8.]
#  [ 10.   8.   1.  10.]
#  [  5.   6.  10.  10.]
#  [  8.   7.  10.   7.]]

# %% [markdown]
# `1.` You will use the **user_movie_subset** matrix to show that your FunkSVD algorithm will converge.  In the below cell, use the comments and document string to assist you as you complete writing your own function to complete FunkSVD.  You may also want to try to complete the function on your own without the assistance of comments.  You may feel free to remove and add to the function in any way that gets you a working solution!
#
# **Notice:** There isn't a sigma matrix in this version of the matrix factorization.

# %%
test = np.random.rand(20, 4)
test
# Out:
# array([[ 0.12867914,  0.53885944,  0.46884822,  0.76266231],
#        [ 0.50572215,  0.00606363,  0.23361502,  0.18294898],
#        [ 0.49018217,  0.48280495,  0.85842977,  0.86820202],
#        [ 0.38490816,  0.52669951,  0.96706151,  0.1491934 ],
#        [ 0.21118031,  0.27391594,  0.70192063,  0.71905517],
#        [ 0.86561484,  0.46339197,  0.19942383,  0.87807743],
#        [ 0.64146445,  0.17797559,  0.57210418,  0.50769301],
#        [ 0.13959601,  0.18899785,  0.71259829,  0.1879679 ],
#        [ 0.27350673,  0.07266787,  0.8186968 ,  0.70278074],
#        [ 0.24006367,  0.19015328,  0.07673522,  0.81644354],
#        [ 0.91367931,  0.49598593,  0.1182234 ,  0.94815572],
#        [ 0.99034405,  0.02657686,  0.38544999,  0.7326621 ],
#        [ 0.57989189,  0.2623037 ,  0.95541494,  0.26512844],
#        [ 0.52983518,  0.5184622 ,  0.82196717,  0.82578019],
#        [ 0.64428815,  0.96975551,  0.18803231,  0.82029411],
#        [ 0.75870409,  0.96930222,  0.7139419 ,  0.40257704],
#        [ 0.11196357,  0.36799364,  0.96533573,  0.99886113],
#        [ 0.3643261 ,  0.60939529,  0.73588543,  0.4016301 ],
#        [ 0.79130633,  0.86753098,  0.0531134 ,  0.8038885 ],
#        [ 0.16075874,  0.60028924,  0.61601671,  0.0920906 ]])

# %%
test[:,0]
# Out:
# array([ 0.12867914,  0.50572215,  0.49018217,  0.38490816,  0.21118031,
#         0.86561484,  0.64146445,  0.13959601,  0.27350673,  0.24006367,
#         0.91367931,  0.99034405,  0.57989189,  0.52983518,  0.64428815,
#         0.75870409,  0.11196357,  0.3643261 ,  0.79130633,  0.16075874])

# %%
def FunkSVD(ratings_mat, latent_features=4, learning_rate=0.0001, iters=100):
    '''
    This function performs matrix factorization using a basic form of FunkSVD with no regularization
    
    INPUT:
    ratings_mat - (numpy array) a matrix with users as rows, movies as columns, and ratings as values
    latent_features - (int) the number of latent features used
    learning_rate - (float) the learning rate 
    iters - (int) the number of iterations
    
    OUTPUT:
    user_mat - (numpy array) a user by latent feature matrix
    movie_mat - (numpy array) a latent feature by movie matrix
    '''
    
    # Set up useful values to be used through the rest of the function
    n_users = ratings_mat.shape[0] # number of rows in the matrix
    n_movies = ratings_mat.shape[1] # number of movies in the matrix
    num_ratings = n_users * n_movies # total number of ratings in the matrix 
    num_ratings_no_nan = np.count_nonzero(~np.isnan(ratings_mat))
    
    # initialize the user and movie matrices with random values
    # helpful link: https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.rand.html
    user_mat = np.random.rand(n_users, latent_features) # user matrix filled with random values of shape user x latent 
    movie_mat = np.random.rand(latent_features, n_movies) # movie matrix filled with random values of shape latent x movies
    
    # initialize sse at 0 for first iteration
    sse_accum = 0
    
    # header for running results
    print("Optimization Statistics")
    print("Iterations | Mean Squared Error ")
    
    # for each iteration
    for epoch in range(iters):

        # update our sse
        old_sse = sse_accum
        sse_accum = 0
        
        # For each user-movie pair
        for um, i in np.ndenumerate(ratings_mat):
                
            # if the rating exists
            if not np.isnan(i):

                # compute the error as the actual minus the dot product of the user and movie latent features
                err = m - np.dot(user_mat[um[0]], movie_mat[:,um[1]])

                # Keep track of the total sum of squared errors for the matrix
                sse_accum += err**2

                # update the values in each matrix in the direction of the gradient
                user_mat_new = user_mat[um[0]] + learning_rate*2*(err)*movie_mat[:,um[1]]
                movie_mat_new = movie_mat[:,um[1]] + learning_rate*2*(err)*user_mat[um[0]]

                user_mat[um[0]] = user_mat_new
                movie_mat[:,um[1]] = movie_mat_new

        # print results for iteration
        print('SSE for iteration {} was {}'.format(epoch, old_sse))
        
    return user_mat, movie_mat

# %% [markdown]
# `2.` Try out your function on the **user_movie_subset** dataset.  First try 4 latent features, a learning rate of 0.005, and 10 iterations.  When you take the dot product of the resulting U and V matrices, how does the resulting **user_movie** matrix compare to the original subset of the data?

# %%
user_mat, movie_mat = FunkSVD(ratings_mat, latent_features=4, learning_rate=0.005, iters=10)

# use your function with 4 latent features, lr of 0.005 and 10 iterations
# Out:
# Optimization Statistics
# Iterations | Mean Squared Error
# SSE for iteration 0 was 0
# SSE for iteration 1 was 1925.4930836507597
# SSE for iteration 2 was 668.9207572340066
# SSE for iteration 3 was 124.92640804456794
# SSE for iteration 4 was 19.621987808074163
# SSE for iteration 5 was 4.917460074688792
# SSE for iteration 6 was 1.937419576817246
# SSE for iteration 7 was 1.0759968639001911
# SSE for iteration 8 was 0.7980092932166124
# SSE for iteration 9 was 0.6983250688555594

# %%
#Compare the predicted and actual results
print(np.dot(user_mat, movie_mat))
print(ratings_mat)
# Out:
# [[ 6.81178169  6.9719403   6.8775809   7.11845676]
#  [ 6.84949344  6.94048797  6.95680026  7.18243602]
#  [ 6.87015698  6.96823466  7.03831167  7.07990256]
#  [ 7.028219    7.00485478  7.05203398  6.94173022]
#  [ 7.02777043  7.1051204   6.95157509  6.96716416]
#  [ 6.99444397  7.08195506  6.97116237  7.03098438]
#  [ 7.05162492  7.05266791  7.03807065  6.91213322]
#  [ 6.85662565  6.95514989  7.01085635  7.10407199]
#  [ 7.02432604  7.07308572  6.98072176  6.99258059]
#  [ 7.06925252  7.12017462  6.85521031  6.97570442]
#  [ 7.23237668  7.04479588  7.07624474  6.74975303]
#  [ 6.93509916  6.93999332  6.97198991  7.10556391]
#  [ 7.07900881  7.04581346  6.95621025  6.93266521]
#  [ 6.93813463  7.00723     6.98769801  7.08960681]
#  [ 6.92235793  6.942258    6.98623696  7.10576635]
#  [ 7.03097388  6.98971605  7.01633874  6.98820306]
#  [ 6.85309436  7.02592181  7.02384533  7.0194287 ]
#  [ 7.00356027  6.90881075  6.986041    7.07356537]
#  [ 7.00751282  6.97332184  7.07532505  6.96070912]
#  [ 7.14508277  6.96875732  7.09131724  6.81291075]]
# [[ nan  10.  10.  10.]
#  [ 10.   4.   9.  10.]
#  [  8.   9.  10.   5.]
#  [  9.   8.  10.  10.]
#  [ 10.   5.   9.   9.]
#  [  6.   4.  10.   6.]
#  [  9.   8.  10.   9.]
#  [ 10.   5.   9.   8.]
#  [  7.   8.  10.   8.]
#  [  9.   5.   9.   7.]
#  [  9.   8.  10.   8.]
#  [  9.  10.  10.   9.]
#  [ 10.   9.  10.   8.]
#  [  5.   8.   5.   8.]
#  [ 10.   8.  10.  10.]
#  [  9.   9.  10.  10.]
#  [  9.   8.   8.   8.]
#  [ 10.   8.   1.  10.]
#  [  5.   6.  10.  10.]
#  [  8.   7.  10.   7.]]

# %% [markdown]
# **Write your summary here.**

# %% [markdown]
# `3.` Let's try out the function again on the **user_movie_subset** dataset.  This time we will again use 4 latent features and a learning rate of 0.005.  However, let's bump up the number of iterations to 250.  When you take the dot product of the resulting U and V matrices, how does the resulting **user_movie** matrix compare to the original subset of the data?  What do you notice about your error at the end of the 250 iterations?

# %%
user_mat, movie_mat = FunkSVD(ratings_mat, latent_features=4, learning_rate=0.005, iters=250) 
#use your function with 4 latent features, lr of 0.005 and 250 iterations
# Out:
# Optimization Statistics
# Iterations | Mean Squared Error
# SSE for iteration 0 was 0
# SSE for iteration 1 was 2315.571119958462
# SSE for iteration 2 was 979.4263679766243
# SSE for iteration 3 was 242.44719744420348
# SSE for iteration 4 was 46.33646352832611
# SSE for iteration 5 was 11.07003443538508
# SSE for iteration 6 was 3.573809292763809
# SSE for iteration 7 was 1.417488878722882
# SSE for iteration 8 was 0.6966705125129221
# SSE for iteration 9 was 0.43780907808374525
# SSE for iteration 10 was 0.3386166703480573
# SSE for iteration 11 was 0.29690712042901396
# SSE for iteration 12 was 0.27665413452926535
# SSE for iteration 13 was 0.264742288403893
# SSE for iteration 14 was 0.2562488852701053
# SSE for iteration 15 was 0.2492671624782812
# SSE for iteration 16 was 0.24303281544579863
# SSE for iteration 17 was 0.23722705123375154
# SSE for iteration 18 was 0.2317101142135887
# SSE for iteration 233 was 0.016105727892969303
# SSE for iteration 234 was 0.015977591520346435
# SSE for iteration 235 was 0.015850703032011457
# SSE for iteration 236 was 0.01572504675002723
# SSE for iteration 237 was 0.015600607250800338
# SSE for iteration 238 was 0.015477369359939541
# SSE for iteration 239 was 0.01535531814724397
# SSE for iteration 240 was 0.01523443892180701
# SSE for iteration 241 was 0.01511471722723811
# SSE for iteration 242 was 0.014996138836999897
# SSE for iteration 243 was 0.01487868974985627
# SSE for iteration 244 was 0.014762356185424064
# SSE for iteration 245 was 0.014647124579835741
# SSE for iteration 246 was 0.014532981581498896
# SSE for iteration 247 was 0.014419914046956979
# SSE for iteration 248 was 0.0143079090368463
# SSE for iteration 249 was 0.014196953811947285

# %%
#Compare the predicted and actual results
print(np.dot(user_mat, movie_mat))
print(ratings_mat)
# Out:
# [[ 6.99857986  6.99960705  6.99890361  7.00120609]
#  [ 6.99844792  7.00227012  6.99366814  7.00479762]
#  [ 6.99761897  7.00564072  6.98568537  7.00975186]
#  [ 7.00079695  6.99592972  7.0096114   6.994282  ]
#  [ 6.99555423  7.0134946   6.96689797  7.02150398]
#  [ 6.99539452  7.01116336  6.97179992  7.01921341]
#  [ 6.99875505  7.00317271  6.99219907  7.00543609]
#  [ 7.00030009  7.00262991  6.9948819   7.00252242]
#  [ 6.99819139  7.00313395  6.99171815  7.00626423]
#  [ 7.00838135  6.97772288  7.0559423   6.96303128]
#  [ 6.99874492  7.00542456  6.98727939  7.0078533 ]
#  [ 7.00443656  6.99113918  7.02333112  6.98365656]
#  [ 6.99977072  6.99787518  7.00438293  6.99796615]
#  [ 6.99940746  7.00125419  6.99679863  7.0022347 ]
#  [ 7.00365286  6.98979775  7.02539695  6.98330209]
#  [ 6.99978063  6.99847404  7.00309076  6.99855768]
#  [ 7.00006094  6.99697743  7.00656943  6.99648736]
#  [ 6.99885449  7.00632307  6.98534552  7.00863854]
#  [ 6.9986453   7.00495871  6.98814426  7.0074046 ]
#  [ 7.00052691  6.99916843  7.00232345  6.99827812]]
# [[ nan  10.  10.  10.]
#  [ 10.   4.   9.  10.]
#  [  8.   9.  10.   5.]
#  [  9.   8.  10.  10.]
#  [ 10.   5.   9.   9.]
#  [  6.   4.  10.   6.]
#  [  9.   8.  10.   9.]
#  [ 10.   5.   9.   8.]
#  [  7.   8.  10.   8.]
#  [  9.   5.   9.   7.]
#  [  9.   8.  10.   8.]
#  [  9.  10.  10.   9.]
#  [ 10.   9.  10.   8.]
#  [  5.   8.   5.   8.]
#  [ 10.   8.  10.  10.]
#  [  9.   9.  10.  10.]
#  [  9.   8.   8.   8.]
#  [ 10.   8.   1.  10.]
#  [  5.   6.  10.  10.]
#  [  8.   7.  10.   7.]]

# %% [markdown]
# **Write your summary here.**

# %% [markdown]
# The last time we placed an **np.nan** value into this matrix the entire svd algorithm in python broke.  Let's see if that is still the case using your FunkSVD function.  In the below cell, I have placed a nan into the first cell of your numpy array.
#
# `4.` Use 4 latent features, a learning rate of 0.005, and 250 iterations.  Are you able to run your SVD without it breaking (something that was not true about the python built in)?  Do you get a prediction for the nan value?  What is your prediction for the missing value? Use the cells below to answer these questions.

# %%
# Here we are placing a nan into our original subset matrix
ratings_mat[0, 0] = np.nan
ratings_mat
# Out:
# matrix([[ nan,  10.,  10.,  10.],
#         [ 10.,   4.,   9.,  10.],
#         [  8.,   9.,  10.,   5.],
#         [  9.,   8.,  10.,  10.],
#         [ 10.,   5.,   9.,   9.],
#         [  6.,   4.,  10.,   6.],
#         [  9.,   8.,  10.,   9.],
#         [ 10.,   5.,   9.,   8.],
#         [  7.,   8.,  10.,   8.],
#         [  9.,   5.,   9.,   7.],
#         [  9.,   8.,  10.,   8.],
#         [  9.,  10.,  10.,   9.],
#         [ 10.,   9.,  10.,   8.],
#         [  5.,   8.,   5.,   8.],
#         [ 10.,   8.,  10.,  10.],
#         [  9.,   9.,  10.,  10.],
#         [  9.,   8.,   8.,   8.],
#         [ 10.,   8.,   1.,  10.],
#         [  5.,   6.,  10.,  10.],
#         [  8.,   7.,  10.,   7.]])

# %%
# run SVD on the matrix with the missing value
user_mat, movie_mat = FunkSVD(ratings_mat, latent_features=4, learning_rate=0.005, iters=250)
#use your function with 4 latent features, lr of 0.005 and 250 iterations
# Out:
# Optimization Statistics
# Iterations | Mean Squared Error
# SSE for iteration 0 was 0
# SSE for iteration 1 was 2269.558661899801
# SSE for iteration 2 was 929.2740766553768
# SSE for iteration 3 was 208.03937592110756
# SSE for iteration 4 was 32.163653145401334
# SSE for iteration 5 was 6.5250789903442925
# SSE for iteration 6 was 2.5545564074989664
# SSE for iteration 7 was 1.6472994856458187
# SSE for iteration 8 was 1.3607544991126166
# SSE for iteration 9 was 1.2396585147750006
# SSE for iteration 10 was 1.1687649255457857
# SSE for iteration 11 was 1.114919734307955
# SSE for iteration 12 was 1.0680663893011901
# SSE for iteration 13 was 1.025004001099795
# SSE for iteration 14 was 0.9846210316808736
# SSE for iteration 15 was 0.9464610069625926
# SSE for iteration 16 was 0.910283372166192
# SSE for iteration 17 was 0.8759259787814719
# SSE for iteration 18 was 0.8432603038907973
# SSE for iteration 19 was 0.8121757949883726
# SSE for iteration 20 was 0.7825737119820233
# SSE for iteration 21 was 0.7543642728486036
# SSE for iteration 22 was 0.7274650700258832
# SSE for iteration 23 was 0.7018000447559446
# SSE for iteration 24 was 0.6772987439367685
# SSE for iteration 25 was 0.6538957395159603
# SSE for iteration 26 was 0.6315301515188796
# SSE for iteration 27 was 0.6101452427127028
# SSE for iteration 28 was 0.5896880661140079
# SSE for iteration 29 was 0.5701091535926113
# SSE for iteration 30 was 0.5513622378081953
# SSE for iteration 31 was 0.5334040020675099
# SSE for iteration 32 was 0.5161938541284236
# SSE for iteration 33 was 0.49969372089163233
# SSE for iteration 34 was 0.48386786152701217
# SSE for iteration 35 was 0.46868269700315085
# SSE for iteration 36 was 0.454106654296335
# SSE for iteration 37 was 0.44011002379049474
# SSE for iteration 38 was 0.42666482856700794
# SSE for iteration 39 was 0.41374470443716854
# SSE for iteration 40 was 0.40132478969984825
# SSE for iteration 41 was 0.38938162371798957
# SSE for iteration 42 was 0.37789305350395147
# SSE for iteration 43 was 0.36683814758814143
# SSE for iteration 44 was 0.356197116519549
# SSE for iteration 45 was 0.3459512394124885
# SSE for iteration 189 was 0.022907430025044005
# SSE for iteration 190 was 0.02260318887195123
# SSE for iteration 191 was 0.0223037679842326
# SSE for iteration 192 was 0.022009072616299207
# SSE for iteration 193 was 0.021719010308453558
# SSE for iteration 194 was 0.02143349082176521
# SSE for iteration 195 was 0.021152426075054825
# SSE for iteration 196 was 0.02087573008391871
# SSE for iteration 197 was 0.02060331890171384
# SSE for iteration 198 was 0.02033511056244599
# SSE for iteration 199 was 0.02007102502547278
# SSE for iteration 200 was 0.019810984121978764
# SSE for iteration 201 was 0.019554911503145114
# SSE for iteration 202 was 0.019302732589959244
# SSE for iteration 203 was 0.01905437452460516
# SSE for iteration 204 was 0.01880976612338264
# SSE for iteration 205 was 0.018568837831099756
# SSE for iteration 206 was 0.01833152167688023
# SSE for iteration 207 was 0.018097751231352766
# SSE for iteration 208 was 0.017867461565158182
# SSE for iteration 209 was 0.01764058920873728
# SSE for iteration 210 was 0.017417072113353086
# SSE for iteration 211 was 0.017196849613310455
# SSE for iteration 212 was 0.01697986238931822
# SSE for iteration 213 was 0.01676605243297445
# SSE for iteration 214 was 0.0165553630123185
# SSE for iteration 215 was 0.016347738638425605
# SSE for iteration 216 was 0.016143125033005606
# SSE for iteration 217 was 0.015941469096967566
# SSE for iteration 218 was 0.015742718879927294
# SSE for iteration 219 was 0.015546823550615093
# SSE for iteration 220 was 0.015353733368163782
# SSE for iteration 221 was 0.015163399654242873
# SSE for iteration 222 was 0.014975774766009154
# SSE for iteration 223 was 0.014790812069852175
# SSE for iteration 224 was 0.014608465915903725
# SSE for iteration 225 was 0.014428691613289671
# SSE for iteration 226 was 0.014251445406097919
# SSE for iteration 227 was 0.014076684450038842
# SSE for iteration 228 was 0.013904366789778756
# SSE for iteration 229 was 0.013734451336921364
# SSE for iteration 230 was 0.013566897848616527
# SSE for iteration 231 was 0.013401666906782048
# SSE for iteration 232 was 0.013238719897907926
# SSE for iteration 233 was 0.013078018993434803
# SSE for iteration 234 was 0.012919527130686058
# SSE for iteration 235 was 0.012763207994328596
# SSE for iteration 236 was 0.012609025998356303
# SSE for iteration 237 was 0.01245694626857513
# SSE for iteration 238 was 0.012306934625568602
# SSE for iteration 239 was 0.012158957568143294
# SSE for iteration 240 was 0.012012982257220283
# SSE for iteration 241 was 0.011868976500173866
# SSE for iteration 242 was 0.011726908735598932
# SSE for iteration 243 was 0.01158674801849278
# SSE for iteration 244 was 0.011448464005835947
# SSE for iteration 245 was 0.011312026942567993
# SSE for iteration 246 was 0.011177407647938077
# SSE for iteration 247 was 0.011044577502223865
# SSE for iteration 248 was 0.010913508433805208
# SSE for iteration 249 was 0.010784172906583317

# %%
# Run this cell to see if you were able to predict for the missing value
preds = np.dot(user_mat, movie_mat)
print("The predicted value for the missing rating is {}:".format(preds[0,0]))
print()
print("The actual value for the missing rating is {}:".format(ratings_mat[0,0]))
print()
assert np.isnan(preds[0,0]) == False
print("That's right! You just predicted a rating for a user-movie pair that was never rated!")
print("But if you look in the original matrix, this was actually a value of 10. Not bad!")
# Out:
# The predicted value for the missing rating is 7.000117344369468:
#
# The actual value for the missing rating is nan:
#
# That's right! You just predicted a rating for a user-movie pair that was never rated!
# But if you look in the original matrix, this was actually a value of 10. Not bad!

# %% [markdown]
# Now let's extend this to a more realistic example. Unfortunately, running this function on your entire user-movie matrix is still not something you likely want to do on your local machine.  However, we can see how well this example extends to 1000 users.  In the above portion, you were using a very small subset of data with no missing values.
#
# `5.` Given the size of this matrix, this will take quite a bit of time.  Consider the following hyperparameters: 4 latent features, 0.005 learning rate, and 20 iterations.  Grab a snack, take a walk, and this should be done running in a bit.

# %%
test_mat = np.random.rand(1000, 4)
test_mat
# Out:
# array([[ 0.4953832 ,  0.74414991,  0.93349891,  0.70396165],
#        [ 0.94526395,  0.21015924,  0.22856984,  0.71553184],
#        [ 0.16186405,  0.2883699 ,  0.65551109,  0.85632443],
#        ...,
#        [ 0.14117475,  0.40133975,  0.89170142,  0.1311931 ],
#        [ 0.44878267,  0.92438063,  0.47296387,  0.71695711],
#        [ 0.88737798,  0.10178655,  0.54221707,  0.72907915]])

# %%
# Setting up a matrix of the first 1000 users with movie ratings
first_1000_users = np.matrix(user_by_movie.head(1000))

# perform funkSVD on the matrix of the top 1000 users
user_mat, movie_mat = FunkSVD(first_1000_users, latent_features=4, learning_rate=0.005, iters=10)
#fit to 1000 users with 4 latent features, lr of 0.005, and 20 iterations
# Out:
# Optimization Statistics
# Iterations | Mean Squared Error
# SSE for iteration 0 was 0
# SSE for iteration 1 was 195917.4526184463
# SSE for iteration 2 was 82785.43637870147
# SSE for iteration 3 was 53003.13528533829
# SSE for iteration 4 was 38671.0968481775
# SSE for iteration 5 was 29867.617707730533
# SSE for iteration 6 was 23846.671377118677
# SSE for iteration 7 was 19473.102173277286
# SSE for iteration 8 was 16167.497314301634
# SSE for iteration 9 was 13594.321839582333

# %% [markdown]
# `6.` Now that you have a set of predictions for each user-movie pair,  let's answer a few questions about your results. Provide the correct values for each of the variables below, and check your solutions using the tests below.

# %%
np.dot(user_mat, movie_mat).shape[0] * np.dot(user_mat, movie_mat).shape[1]
# Out:
# (1000, 31245)

# %%
movie_mat.shape
# Out:
# (4, 31245)

# %%
# Replace each of the comments below with the correct values
num_ratings = np.count_nonzero(~np.isnan(first_1000_users)) # How many actual ratings exist in first_1000_users
print("The number of actual ratings in the first_1000_users is {}.".format(num_ratings))
print()


ratings_for_missing = np.dot(user_mat, movie_mat).shape[0] * np.dot(user_mat, movie_mat).shape[1] - num_ratings# How many ratings did we make for user-movie pairs that didn't actually have ratings
print("The number of ratings made for user-movie pairs that didn't have ratings is {}".format(ratings_for_missing))
# Out:
# The number of actual ratings in the first_1000_users is 10852.
#
# The number of ratings made for user-movie pairs that didn't have ratings is 31234148

# %%
# Test your results against the solution
assert num_ratings == 10852, "Oops!  The number of actual ratings doesn't quite look right."
assert ratings_for_missing == 31234148, "Oops!  The number of movie-user pairs that you made ratings for that didn't actually have ratings doesn't look right."

# Make sure you made predictions on all the missing user-movie pairs
preds = np.dot(user_mat, movie_mat)
assert np.isnan(preds).sum() == 0
print("Nice job!  Looks like you have predictions made for all the missing user-movie pairs! But I still have one question... How good are they?")
# Out:
# Nice job!  Looks like you have predictions made for all the missing user-movie pairs! But I still have one question... How good are they?
